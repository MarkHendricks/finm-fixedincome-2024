# %% [markdown]
# # WRDS CRSP Documentation
#
# ### Treasury Libraries
# `crsp_m_treasuries`
#
# Quote Data
# * tfz_dly: main file of treasury quotes
# * tfz_dly_ts2: supplemental series
# * tfz_dly_ft: matched to term structure at any given date
# * tfz_dly_cd: compilation of fed reported rates in tfz format
# * tfz_dly_cpi: compilation of cpi data
# * tfz_dly_rf2: compiled risk-free rate
#
# Identifying Info
# * tfz_iss: issue details (which are included automatically in queries.)
# * tfz_idx: description of KYTREASNOX codes

# %% [markdown]
# ### WRDS Python Manual
# https://wrds-www.wharton.upenn.edu/pages/support/programming-wrds/programming-python/querying-wrds-data-python/
#
# https://wrds-www.wharton.upenn.edu/pages/support/programming-wrds/programming-python/python-example-data-workflow/
#
# https://wrds-www.wharton.upenn.edu/pages/support/applications/python-replications/fama-french-factors-python/

# %% [markdown]
# ### CRSP Treasury Manual
#
# https://www.crsp.org/products/documentation/treasno-properties
# https://www.crsp.org/products/documentation/reference-information

# %%
import wrds
file_key = open("../../keys/wrds_username.txt","r")
USERNAME = file_key.read()
file_key.close()

db = wrds.Connection(wrds_username=USERNAME)
#db.create_pgpass_file()
# Out:
# Loading library list...
# Done

# %%
import pandas as pd
import numpy as np
from datetime import date

# %% [markdown]
# # Library Info

# %%
libs = db.list_libraries()
libs_crsp = [item for item in libs if item.startswith('crsp')]
treasury_databases = db.list_tables('crsp_m_treasuries')
display(treasury_databases)
# Out:
# ['tfz_dly',
#  'tfz_dly_cd',
#  'tfz_dly_cpi',
#  'tfz_dly_ft',
#  'tfz_dly_rf2',
#  'tfz_dly_ts2',
#  'tfz_idx',
#  'tfz_iss',
#  'tfz_mast',
#  'tfz_mth',
#  'tfz_mth_bp',
#  'tfz_mth_cd',
#  'tfz_mth_cpi',
#  'tfz_mth_fb',
#  'tfz_mth_ft',
#  'tfz_mth_rf',
#  'tfz_mth_rf2',
#  'tfz_mth_ts',
#  'tfz_mth_ts2',
#  'tfz_pay']

# %%
db.describe_table(library='crsp_m_treasuries', table='tfz_dly')
# Out:
# Approximately 3384880 rows in crsp_m_treasuries.tfz_dly.
#               name  nullable              type comment
# 0        kytreasno      True  DOUBLE_PRECISION    None
# 1         kycrspid      True       VARCHAR(15)    None
# 2            caldt      True              DATE    None
# 3            tdbid      True  DOUBLE_PRECISION    None
# 4            tdask      True  DOUBLE_PRECISION    None
# 5         tdnomprc      True  DOUBLE_PRECISION    None
# 6     tdnomprc_flg      True        VARCHAR(1)    None
# 7         tdsourcr      True        VARCHAR(1)    None
# 8         tdaccint      True  DOUBLE_PRECISION    None
# 9         tdretnua      True  DOUBLE_PRECISION    None
# 10           tdyld      True  DOUBLE_PRECISION    None
# 11        tdduratn      True  DOUBLE_PRECISION    None
# 12        tdpubout      True  DOUBLE_PRECISION    None
# 13        tdtotout      True  DOUBLE_PRECISION    None
# 14         tdpdint      True  DOUBLE_PRECISION    None
# 15      tdidxratio      True  DOUBLE_PRECISION    None
# 16  tdidxratio_flg      True        VARCHAR(1)    None

# %% [markdown]
# # Database quote

# %%
DATE = '2023-12-29'
SQL_QUERY = f'select * from crsp_m_treasuries.tfz_dly where caldt=\'{DATE}\''
data_quotes = db.raw_sql(SQL_QUERY)
data_quotes
# Out:
#      kytreasno         kycrspid       caldt       tdbid       tdask  \
# 0     204087.0  20260815.106750  2023-12-29  106.656250  106.687500
# 1     204091.0  20271115.106120  2023-12-29  108.093750  108.140625
# 2     204095.0  20290815.106120  2023-12-29  111.039062  111.085938
# 3     206058.0  20390515.104250  2023-12-29  103.093750  103.156250
# 4     206086.0  20391115.104370  2023-12-29  104.281250  104.343750
# ..         ...              ...         ...         ...         ...
# 438   208133.0  20301031.204870  2023-12-29  105.832031  105.878906
# 439   208134.0  20240312.400000  2023-12-29   98.933167   98.935222
# 440   208143.0  20251130.204870  2023-12-29  101.039062  101.070312
# 441   208149.0  20531115.104750  2023-12-29  112.437500  112.500000
# 442   208150.0  20240409.400000  2023-12-29   98.529500   98.532333
#
#        tdnomprc tdnomprc_flg tdsourcr  tdaccint  tdretnua     tdyld  \
# 0    106.671875            M        I  2.494565  0.000813  0.000110
# 1    108.117188            M        I  0.740385  0.002962  0.000104
# 2    111.062500            M        I  2.263587 -0.001162  0.000106
# 3    103.125000            M        I  0.513736 -0.003868  0.000108
# 4    104.312500            M        I  0.528846 -0.003894  0.000109
# ..          ...          ...      ...       ...       ...       ...
# 438  105.855469            M        I  0.790179 -0.001119  0.000105
# 439   98.934194            M        I  0.000000  0.000167  0.000145
# 440  101.054688            M        I  0.386270  0.000709  0.000116
# 441  112.468750            M        I  0.574176 -0.005384  0.000109
# 442   98.530917            M        I  0.000000  0.000146  0.000145
#
#         tdduratn  tdpubout  tdtotout  tdpdint  tdidxratio tdidxratio_flg
# 0     878.108869    3670.0    8810.0      0.0         NaN           None
# 1    1280.373664    7775.0   22021.0      0.0         NaN           None
# 2    1751.978172    4014.0   11179.0      0.0         NaN           None
# 3    4184.526115   11634.0   38779.0      0.0         NaN           None
# 4    4256.774843   13370.0   44564.0      0.0         NaN           None
# ..           ...       ...       ...      ...         ...            ...
# 438  2150.093752   38000.0   38000.0      0.0         NaN           None
# 439    74.000000       NaN   56385.0      0.0         NaN           None
# 440   676.492713   54003.0   54626.0      0.0         NaN           None
# 441  6192.957397   44988.0   45445.0      0.0         NaN           None
# 442   102.000000       NaN   56264.0      0.0         NaN           None
#
# [443 rows x 17 columns]

# %%
KEYS = tuple(data_quotes['kytreasno'])
SQL_QUERY = f'select * from crsp_m_treasuries.tfz_iss where kytreasno in {KEYS}'
data_iss = db.raw_sql(SQL_QUERY)
data_iss
# Out:
#      kytreasno         kycrspid           crspid    tcusip      tdatdt  \
# 0     204083.0  20241115.107500  20241115.107500  912810ES  1994-05-15
# 1     204084.0  20250215.107620  20250215.107620  912810ET  1995-02-15
# 2     204085.0  20250815.106870  20250815.106870  912810EV  1995-08-15
# 3     204086.0  20260215.106000  20260215.106000  912810EW  1996-02-15
# 4     204087.0  20260815.106750  20260815.106750  912810EX  1996-08-15
# ..         ...              ...              ...       ...         ...
# 438   208157.0  20241226.400000  20241226.400000  912796ZV  2023-12-28
# 439   208158.0  20251231.204250  20251231.204250  91282CJS  2023-12-31
# 440   208159.0  20261215.204370  20261215.204370  91282CJP  2023-12-15
# 441   208160.0  20281231.203750  20281231.203750  91282CJR  2023-12-31
# 442   208161.0  20301231.203750  20301231.203750  91282CJQ  2023-12-31
#
#          tmatdt  iwhy  tcouprt  tnippy  tvalfc  ... tfcaldt  tnotice iymcn  \
# 0    2024-11-15   0.0    7.500     2.0  3.7500  ...    None      0.0  None
# 1    2025-02-15   0.0    7.625     2.0  3.8125  ...    None      0.0  None
# 2    2025-08-15   0.0    6.875     2.0  3.4375  ...    None      0.0  None
# 3    2026-02-15   0.0    6.000     2.0  3.0000  ...    None      0.0  None
# 4    2026-08-15   0.0    6.750     2.0  3.3750  ...    None      0.0  None
# ..          ...   ...      ...     ...     ...  ...     ...      ...   ...
# 438  2024-12-26   0.0    0.000     0.0  0.0000  ...    None      0.0  None
# 439  2025-12-31   0.0    4.250     2.0  2.1250  ...    None      0.0  None
# 440  2026-12-15   0.0    4.375     2.0  2.1875  ...    None      0.0  None
# 441  2028-12-31   0.0    3.750     2.0  1.8750  ...    None      0.0  None
# 442  2030-12-31   0.0    3.750     2.0  1.8750  ...    None      0.0  None
#
#      itype iuniq  itax  iflwr  tbankdt  tstripelig tfrgntgt
# 0      1.0   0.0   1.0    1.0     None        None     None
# 1      1.0   0.0   1.0    1.0     None        None     None
# 2      1.0   0.0   1.0    1.0     None        None     None
# 3      1.0   0.0   1.0    1.0     None        None     None
# 4      1.0   0.0   1.0    1.0     None        None     None
# ..     ...   ...   ...    ...      ...         ...      ...
# 438    4.0   0.0   1.0    1.0     None        None     None
# 439    2.0   0.0   1.0    1.0     None        None     None
# 440    2.0   0.0   1.0    1.0     None        None     None
# 441    2.0   0.0   1.0    1.0     None        None     None
# 442    2.0   0.0   1.0    1.0     None        None     None
#
# [443 rows x 22 columns]

# %%
data = data_quotes.merge(data_iss, on='kytreasno')
data
# Out:
#      kytreasno       kycrspid_x       caldt       tdbid       tdask  \
# 0     204087.0  20260815.106750  2023-12-29  106.656250  106.687500
# 1     204091.0  20271115.106120  2023-12-29  108.093750  108.140625
# 2     204095.0  20290815.106120  2023-12-29  111.039062  111.085938
# 3     206058.0  20390515.104250  2023-12-29  103.093750  103.156250
# 4     206086.0  20391115.104370  2023-12-29  104.281250  104.343750
# ..         ...              ...         ...         ...         ...
# 438   208133.0  20301031.204870  2023-12-29  105.832031  105.878906
# 439   208134.0  20240312.400000  2023-12-29   98.933167   98.935222
# 440   208143.0  20251130.204870  2023-12-29  101.039062  101.070312
# 441   208149.0  20531115.104750  2023-12-29  112.437500  112.500000
# 442   208150.0  20240409.400000  2023-12-29   98.529500   98.532333
#
#        tdnomprc tdnomprc_flg tdsourcr  tdaccint  tdretnua  ...  tfcaldt  \
# 0    106.671875            M        I  2.494565  0.000813  ...     None
# 1    108.117188            M        I  0.740385  0.002962  ...     None
# 2    111.062500            M        I  2.263587 -0.001162  ...     None
# 3    103.125000            M        I  0.513736 -0.003868  ...     None
# 4    104.312500            M        I  0.528846 -0.003894  ...     None
# ..          ...          ...      ...       ...       ...  ...      ...
# 438  105.855469            M        I  0.790179 -0.001119  ...     None
# 439   98.934194            M        I  0.000000  0.000167  ...     None
# 440  101.054688            M        I  0.386270  0.000709  ...     None
# 441  112.468750            M        I  0.574176 -0.005384  ...     None
# 442   98.530917            M        I  0.000000  0.000146  ...     None
#
#      tnotice  iymcn  itype  iuniq  itax iflwr tbankdt tstripelig tfrgntgt
# 0        0.0   None    1.0    0.0   1.0   1.0    None       None     None
# 1        0.0   None    1.0    0.0   1.0   1.0    None       None     None
# 2        0.0   None    1.0    0.0   1.0   1.0    None       None     None
# 3        0.0   None    1.0    0.0   1.0   1.0    None       None     None
# 4        0.0   None    1.0    0.0   1.0   1.0    None       None     None
# ..       ...    ...    ...    ...   ...   ...     ...        ...      ...
# 438      0.0   None    2.0    0.0   1.0   1.0    None       None     None
# 439      0.0   None    4.0    0.0   1.0   1.0    None       None     None
# 440      0.0   None    2.0    0.0   1.0   1.0    None       None     None
# 441      0.0   None    1.0    0.0   1.0   1.0    None       None     None
# 442      0.0   None    4.0    0.0   1.0   1.0    None       None     None
#
# [443 rows x 38 columns]

# %% [markdown]
# # Selected Maturities

# %%
df = data.copy()
df = df[~df['itype'].isin([11,12])]
df.dropna(subset=['tdduratn'],inplace=True)

# %%
PERIODS_GRID = 21
FREQ = '6M'

# %%
from pandas.tseries.offsets import DateOffset

# Assuming DATE and data are given
# example dataframe 'data' with 'tmatdt' and 'tdatdt' columns

# Convert DATE and columns in 'data' to datetime
dateobj = pd.to_datetime(DATE)
df['tmatdt'] = pd.to_datetime(df['tmatdt'])
df['tdatdt'] = pd.to_datetime(df['tdatdt'])

# Generate 6-month intervals from DATE
six_month_intervals = pd.date_range(start=dateobj, periods=PERIODS_GRID, freq=FREQ) # adjust periods as needed

# Function to find closest date in 'tmatdt' for each interval
def find_closest_date(interval, data):
    # Calculate the absolute difference between each MATURITY date and the interval
    data['difference'] = abs(data['tmatdt'] - interval)
    # Ensure we only consider future dates relative to DATE
    future_dates = data[data['tmatdt'] > dateobj]
    if not future_dates.empty:
        # Find the row with the minimum difference
        min_diff = future_dates['difference'].min()
        closest_dates = future_dates[future_dates['difference'] == min_diff]
        # Resolve ties by 'tdatdt' date
        return closest_dates.sort_values('tdatdt', ascending=False).iloc[0]
    return None

# Apply the function to each interval
selected_rows = [find_closest_date(interval, df) for interval in six_month_intervals]

# Remove None values and ensure uniqueness
selected_rows = [row for row in selected_rows if row is not None]
data_select = pd.DataFrame(selected_rows).drop_duplicates(subset='tmatdt')

# Add new column for years difference
data_select['TTM'] = data_select['tmatdt'].apply(
    lambda x: (x - dateobj).days / 365.25)

data_select = data_select[['kytreasno','caldt','tdatdt','tmatdt','TTM','tdbid','tdask','tdaccint','tdyld','tdduratn','tdtotout','tcouprt','itype']]

data_select['kytreasno'] = data_select['kytreasno'].map('{:.0f}'.format)
data_select = data_select.set_index('kytreasno')

# %%
selected = data_select.rename(columns={'caldt':'date','tdatdt':'issue date','tdtotout':'outstanding','tmatdt':'maturity date','TTM':'ttm','tdbid':'bid','tdask':'ask','tcouprt':'cpn rate','itype':'instrument','tdyld':'ytm','tdaccint':'accrint', 'tdduratn':'duration'})

# eliminate issue 0 years away
selected = selected[~(selected['duration']<30)]

selected.style.format({
    'ttm':'{:.2f}','tdbid':'{:.2f}',
    'ask':'{:.2f}',
    'accrint':'{:.2f}',
    'ytm':'{:.2f}',
    'duration':'{:.2f}',
    'outstanding':'{:,.0f}',
    'cpn rate':'{:.3f}',
    'instrument':'{:.0f}',
    'issue date': lambda x: x.strftime('%Y-%m-%d') if not pd.isnull(x) else '',
    'maturity date': lambda x: x.strftime('%Y-%m-%d') if not pd.isnull(x) else ''
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_5377f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5377f_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_5377f_level0_col1" class="col_heading level0 col1" >issue date</th>
#       <th id="T_5377f_level0_col2" class="col_heading level0 col2" >maturity date</th>
#       <th id="T_5377f_level0_col3" class="col_heading level0 col3" >ttm</th>
#       <th id="T_5377f_level0_col4" class="col_heading level0 col4" >bid</th>
#       <th id="T_5377f_level0_col5" class="col_heading level0 col5" >ask</th>
#       <th id="T_5377f_level0_col6" class="col_heading level0 col6" >accrint</th>
#       <th id="T_5377f_level0_col7" class="col_heading level0 col7" >ytm</th>
#       <th id="T_5377f_level0_col8" class="col_heading level0 col8" >duration</th>
#       <th id="T_5377f_level0_col9" class="col_heading level0 col9" >outstanding</th>
#       <th id="T_5377f_level0_col10" class="col_heading level0 col10" >cpn rate</th>
#       <th id="T_5377f_level0_col11" class="col_heading level0 col11" >instrument</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >kytreasno</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5377f_level0_row0" class="row_heading level0 row0" >207902</th>
#       <td id="T_5377f_row0_col0" class="data row0 col0" >2023-12-29</td>
#       <td id="T_5377f_row0_col1" class="data row0 col1" >2022-06-30</td>
#       <td id="T_5377f_row0_col2" class="data row0 col2" >2024-06-30</td>
#       <td id="T_5377f_row0_col3" class="data row0 col3" >0.50</td>
#       <td id="T_5377f_row0_col4" class="data row0 col4" >98.937500</td>
#       <td id="T_5377f_row0_col5" class="data row0 col5" >98.98</td>
#       <td id="T_5377f_row0_col6" class="data row0 col6" >1.48</td>
#       <td id="T_5377f_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_5377f_row0_col8" class="data row0 col8" >181.28</td>
#       <td id="T_5377f_row0_col9" class="data row0 col9" >49,513</td>
#       <td id="T_5377f_row0_col10" class="data row0 col10" >3.000</td>
#       <td id="T_5377f_row0_col11" class="data row0 col11" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5377f_level0_row1" class="row_heading level0 row1" >207987</th>
#       <td id="T_5377f_row1_col0" class="data row1 col0" >2023-12-29</td>
#       <td id="T_5377f_row1_col1" class="data row1 col1" >2022-12-31</td>
#       <td id="T_5377f_row1_col2" class="data row1 col2" >2024-12-31</td>
#       <td id="T_5377f_row1_col3" class="data row1 col3" >1.01</td>
#       <td id="T_5377f_row1_col4" class="data row1 col4" >99.484375</td>
#       <td id="T_5377f_row1_col5" class="data row1 col5" >99.51</td>
#       <td id="T_5377f_row1_col6" class="data row1 col6" >2.10</td>
#       <td id="T_5377f_row1_col7" class="data row1 col7" >0.00</td>
#       <td id="T_5377f_row1_col8" class="data row1 col8" >356.59</td>
#       <td id="T_5377f_row1_col9" class="data row1 col9" >41,989</td>
#       <td id="T_5377f_row1_col10" class="data row1 col10" >4.250</td>
#       <td id="T_5377f_row1_col11" class="data row1 col11" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5377f_level0_row2" class="row_heading level0 row2" >208073</th>
#       <td id="T_5377f_row2_col0" class="data row2 col0" >2023-12-29</td>
#       <td id="T_5377f_row2_col1" class="data row2 col1" >2023-06-30</td>
#       <td id="T_5377f_row2_col2" class="data row2 col2" >2025-06-30</td>
#       <td id="T_5377f_row2_col3" class="data row2 col3" >1.50</td>
#       <td id="T_5377f_row2_col4" class="data row2 col4" >100.250000</td>
#       <td id="T_5377f_row2_col5" class="data row2 col5" >100.27</td>
#       <td id="T_5377f_row2_col6" class="data row2 col6" >2.29</td>
#       <td id="T_5377f_row2_col7" class="data row2 col7" >0.00</td>
#       <td id="T_5377f_row2_col8" class="data row2 col8" >524.71</td>
#       <td id="T_5377f_row2_col9" class="data row2 col9" >41,994</td>
#       <td id="T_5377f_row2_col10" class="data row2 col10" >4.625</td>
#       <td id="T_5377f_row2_col11" class="data row2 col11" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5377f_level0_row3" class="row_heading level0 row3" >208158</th>
#       <td id="T_5377f_row3_col0" class="data row3 col0" >2023-12-29</td>
#       <td id="T_5377f_row3_col1" class="data row3 col1" >2023-12-31</td>
#       <td id="T_5377f_row3_col2" class="data row3 col2" >2025-12-31</td>
#       <td id="T_5377f_row3_col3" class="data row3 col3" >2.01</td>
#       <td id="T_5377f_row3_col4" class="data row3 col4" >99.984375</td>
#       <td id="T_5377f_row3_col5" class="data row3 col5" >100.02</td>
#       <td id="T_5377f_row3_col6" class="data row3 col6" >0.00</td>
#       <td id="T_5377f_row3_col7" class="data row3 col7" >0.00</td>
#       <td id="T_5377f_row3_col8" class="data row3 col8" >710.47</td>
#       <td id="T_5377f_row3_col9" class="data row3 col9" >nan</td>
#       <td id="T_5377f_row3_col10" class="data row3 col10" >4.250</td>
#       <td id="T_5377f_row3_col11" class="data row3 col11" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5377f_level0_row4" class="row_heading level0 row4" >207731</th>
#       <td id="T_5377f_row4_col0" class="data row4 col0" >2023-12-29</td>
#       <td id="T_5377f_row4_col1" class="data row4 col1" >2021-06-30</td>
#       <td id="T_5377f_row4_col2" class="data row4 col2" >2026-06-30</td>
#       <td id="T_5377f_row4_col3" class="data row4 col3" >2.50</td>
#       <td id="T_5377f_row4_col4" class="data row4 col4" >92.492188</td>
#       <td id="T_5377f_row4_col5" class="data row4 col5" >92.52</td>
#       <td id="T_5377f_row4_col6" class="data row4 col6" >0.43</td>
#       <td id="T_5377f_row4_col7" class="data row4 col7" >0.00</td>
#       <td id="T_5377f_row4_col8" class="data row4 col8" >901.47</td>
#       <td id="T_5377f_row4_col9" class="data row4 col9" >70,259</td>
#       <td id="T_5377f_row4_col10" class="data row4 col10" >0.875</td>
#       <td id="T_5377f_row4_col11" class="data row4 col11" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5377f_level0_row5" class="row_heading level0 row5" >207821</th>
#       <td id="T_5377f_row5_col0" class="data row5 col0" >2023-12-29</td>
#       <td id="T_5377f_row5_col1" class="data row5 col1" >2021-12-31</td>
#       <td id="T_5377f_row5_col2" class="data row5 col2" >2026-12-31</td>
#       <td id="T_5377f_row5_col3" class="data row5 col3" >3.01</td>
#       <td id="T_5377f_row5_col4" class="data row5 col4" >92.335938</td>
#       <td id="T_5377f_row5_col5" class="data row5 col5" >92.36</td>
#       <td id="T_5377f_row5_col6" class="data row5 col6" >0.62</td>
#       <td id="T_5377f_row5_col7" class="data row5 col7" >0.00</td>
#       <td id="T_5377f_row5_col8" class="data row5 col8" >1073.03</td>
#       <td id="T_5377f_row5_col9" class="data row5 col9" >64,744</td>
#       <td id="T_5377f_row5_col10" class="data row5 col10" >1.250</td>
#       <td id="T_5377f_row5_col11" class="data row5 col11" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5377f_level0_row6" class="row_heading level0 row6" >207904</th>
#       <td id="T_5377f_row6_col0" class="data row6 col0" >2023-12-29</td>
#       <td id="T_5377f_row6_col1" class="data row6 col1" >2022-06-30</td>
#       <td id="T_5377f_row6_col2" class="data row6 col2" >2027-06-30</td>
#       <td id="T_5377f_row6_col3" class="data row6 col3" >3.50</td>
#       <td id="T_5377f_row6_col4" class="data row6 col4" >97.726562</td>
#       <td id="T_5377f_row6_col5" class="data row6 col5" >97.75</td>
#       <td id="T_5377f_row6_col6" class="data row6 col6" >1.61</td>
#       <td id="T_5377f_row6_col7" class="data row6 col7" >0.00</td>
#       <td id="T_5377f_row6_col8" class="data row6 co

# %%
# with pd.option_context('display.max_rows',None):
#     display(data_select.sort_values('tdatdt')[['kytreasno','tmatdt','tdatdt','tcouprt']])

# %% [markdown]
# # Get Yield Curve Data (CRSP)

# %%
data_ft = db.get_table(library='crsp_m_treasuries', table='tfz_dly_ft').pivot_table(index='caldt',values='tdytm', columns='kytreasnox')
data_ft.columns = [1,2,5,7,10,20,30]
data_ft
# Out:
#                   1         2         5         7         10        20  \
# caldt
# 1961-06-14  2.935907  3.360687  3.623677  3.768720  3.818819  3.814210
# 1961-06-15  2.932936  3.376460  3.671691  3.804225  3.862987  3.828220
# 1961-06-16  2.929949  3.375670  3.685431  3.804216  3.863282  3.832922
# 1961-06-19  2.920884  3.389970  3.712984  3.824557  3.886205  3.842378
# 1961-06-20  2.952419  3.355796  3.685391  3.809274  3.886506  3.856465
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22  4.812226  4.256188  3.874439  3.818920  3.861111  4.207951
# 2023-12-26  4.820305  4.285033  3.890155  3.833418  3.861196  4.196720
# 2023-12-27  4.825551  4.227558  3.800273  3.732201  3.761121  4.097060
# 2023-12-28  4.843641  4.263434  3.843962  3.781561  3.810347  4.136053
# 2023-12-29  4.700246  4.196261  3.826802  3.855509  3.838445  4.146599
#
#                   30
# caldt
# 1961-06-14  3.815172
# 1961-06-15  3.826316
# 1961-06-16  3.830049
# 1961-06-19  3.837543
# 1961-06-20  3.845018
# ...              ...
# 2023-12-22  4.024439
# 2023-12-26  4.018696
# 2023-12-27  3.929285
# 2023-12-28  3.968281
# 2023-12-29  3.985566
#
# [15618 rows x 7 columns]

# %% [markdown]
# # Get Timeseries for certain maturities

# %%
MATDT = '2041-02-15'

SQL_QUERY = f'select * from crsp_m_treasuries.tfz_iss where tmatdt=\'{MATDT}\''
temp = db.raw_sql(SQL_QUERY)
#temp = temp[temp['itype'].isin([11,12]) == DOTIPS]
temp
# Out:
#    kytreasno         kycrspid           crspid    tcusip      tdatdt  \
# 0   206226.0  20410215.104750  20410215.104750  912810QN  2011-02-15
# 1   206477.0  20410215.B02120  20410215.B02120  912810QP  2011-02-15
# 2   207679.0  20410215.101870  20410215.101870  912810SW  2021-02-15
#
#        tmatdt  iwhy  tcouprt  tnippy  tvalfc  ... tfcaldt  tnotice iymcn  \
# 0  2041-02-15   0.0    4.750     2.0  2.3750  ...    None      0.0  None
# 1  2041-02-15   0.0    2.125     2.0  1.0625  ...    None      0.0  None
# 2  2041-02-15   0.0    1.875     2.0  0.9375  ...    None      0.0  None
#
#    itype iuniq  itax  iflwr  tbankdt  tstripelig tfrgntgt
# 0    1.0   0.0   1.0    1.0     None        None     None
# 1   11.0   0.0   1.0    1.0     None        None     None
# 2    1.0   0.0   1.0    1.0     None        None     None
#
# [3 rows x 22 columns]

# %%
if temp.shape[0]>1:
    KEYNO = tuple(temp['kytreasno'])
    SQL_QUERY = f'select * from crsp_m_treasuries.tfz_dly where kytreasno in {KEYNO}'
else:
    KEYNO = temp['kytreasno'].values[0]
    SQL_QUERY = f'select * from crsp_m_treasuries.tfz_dly where kytreasno =\'{KEYNO}\''
    
ts = db.raw_sql(SQL_QUERY)
ts
# Out:
#       kytreasno         kycrspid       caldt       tdbid       tdask  \
# 0      206226.0  20410215.104750  2011-02-11  100.953125  101.031250
# 1      206226.0  20410215.104750  2012-06-20  141.828125  141.906250
# 2      206226.0  20410215.104750  2012-06-21  143.195312  143.210938
# 3      206226.0  20410215.104750  2012-06-22  141.289062  141.367188
# 4      206226.0  20410215.104750  2012-06-25  143.468750  143.515625
# ...         ...              ...         ...         ...         ...
# 7106   206477.0  20410215.B02120  2013-01-16  146.531250  147.015625
# 7107   206477.0  20410215.B02120  2013-01-17  145.609375  145.640625
# 7108   206477.0  20410215.B02120  2013-01-18  146.597656  147.078125
# 7109   206477.0  20410215.B02120  2013-01-22  146.417969  146.898438
# 7110   206477.0  20410215.B02120  2013-01-23  146.824219  147.304688
#
#         tdnomprc tdnomprc_flg tdsourcr  tdaccint  tdretnua     tdyld  \
# 0     100.992188            M        I  0.000000       NaN  0.000127
# 1     141.867188            M        I  1.644231  0.000091  0.000072
# 2     143.203125            M        I  1.657280  0.009400  0.000071
# 3     141.328125            M        I  1.670330 -0.012853  0.000073
# 4     143.492188            M        I  1.709478  0.015407  0.000070
# ...          ...          ...      ...       ...       ...       ...
# 7106  146.773438            M        I  0.000000       NaN       NaN
# 7107  145.625000            M        I  0.000000       NaN       NaN
# 7108  146.837891            M        I  0.000000       NaN       NaN
# 7109  146.658203            M        I  0.000000       NaN       NaN
# 7110  147.064453            M        I  0.000000       NaN       NaN
#
#          tdduratn  tdpubout  tdtotout  tdpdint  tdidxratio tdidxratio_flg
# 0     5976.516147       NaN       NaN      0.0         NaN           None
# 1     6515.711044   28654.0   43005.0      0.0         NaN           None
# 2     6534.197013   28654.0   43005.0      0.0         NaN           None
# 3     6505.866039   28654.0   43005.0      0.0         NaN           None
# 4     6534.532287   28654.0   43005.0      0.0         NaN           None
# ...           ...       ...       ...      ...         ...            ...
# 7106          NaN   13008.0   25335.0      0.0     1.05386              C
# 7107          NaN   13008.0   25335.0      0.0     1.05370              C
# 7108          NaN   13008.0   25335.0      0.0     1.05354              C
# 7109          NaN   13008.0   25335.0      0.0     1.05290              C
# 7110          NaN   13008.0   25335.0      0.0     1.05273              C
#
# [7111 rows x 17 columns]

# %% [markdown]
# # Get Timeseries for certain issues

# %%
KEYNO_ts = (208053,208055)
#KEYNO_ts = (208140,208142)
#KEYNO_ts = (207816,207818)
#KEYNO_ts = (206980,207213)

SQL_QUERY = f'select * from crsp_m_treasuries.tfz_dly where kytreasno in {KEYNO_ts}'

ts_issue = db.raw_sql(SQL_QUERY)
ts_issue
# Out:
#      kytreasno         kycrspid       caldt      tdbid      tdask   tdnomprc  \
# 0     208053.0  20231116.400000  2023-11-02  99.795056  99.795444  99.795250
# 1     208053.0  20231116.400000  2023-11-03  99.809694  99.810056  99.809875
# 2     208053.0  20231116.400000  2023-11-06  99.853472  99.853750  99.853611
# 3     208053.0  20231116.400000  2023-11-07  99.868500  99.868750  99.868625
# 4     208053.0  20231116.400000  2023-11-08  99.883111  99.883333  99.883222
# ..         ...              ...         ...        ...        ...        ...
# 265   208055.0  20240516.400000  2023-11-16  97.381222  97.383750  97.382486
# 266   208055.0  20240516.400000  2023-11-17  97.390583  97.395611  97.393097
# 267   208055.0  20240516.400000  2023-11-20  97.419000  97.428889  97.423944
# 268   208055.0  20240516.400000  2023-11-21  97.440875  97.445792  97.443333
# 269   208055.0  20240516.400000  2023-11-22  97.450444  97.455333  97.452889
#
#     tdnomprc_flg tdsourcr  tdaccint  tdretnua     tdyld  tdduratn tdpubout  \
# 0              M        I       0.0  0.000150  0.000146      14.0     None
# 1              M        I       0.0  0.000147  0.000146      13.0     None
# 2              M        I       0.0  0.000438  0.000146      10.0     None
# 3              M        I       0.0  0.000150  0.000146       9.0     None
# 4              M        I       0.0  0.000146  0.000146       8.0     None
# ..           ...      ...       ...       ...       ...       ...      ...
# 265            M        I       0.0  0.000317  0.000146     182.0     None
# 266            M        I       0.0  0.000109  0.000146     181.0     None
# 267            M        I       0.0  0.000317  0.000147     178.0     None
# 268            M        I       0.0  0.000199  0.000146     177.0     None
# 269            M        I       0.0  0.000098  0.000147     176.0     None
#
#      tdtotout  tdpdint tdidxratio tdidxratio_flg
# 0    198786.0      0.0       None           None
# 1    198786.0      0.0       None           None
# 2    198786.0      0.0       None           None
# 3    198786.0      0.0       None           None
# 4    198786.0      0.0       None           None
# ..        ...      ...        ...            ...
# 265   40694.0      0.0       None           None
# 266   40694.0      0.0       None           None
# 267   40694.0      0.0       None           None
# 268   40694.0      0.0       None           None
# 269   40694.0      0.0       None           None
#
# [270 rows x 17 columns]

# %%
SQL_QUERY = f'select * from crsp_m_treasuries.tfz_iss where kytreasno in {KEYNO_ts}'
temp = db.raw_sql(SQL_QUERY)
temp
# Out:
#    kytreasno         kycrspid           crspid    tcusip      tdatdt  \
# 0   208053.0  20231116.400000  20231116.400000  912797FK  2023-05-18
# 1   208055.0  20240516.400000  20240516.400000  912797FH  2023-05-18
#
#        tmatdt  iwhy  tcouprt  tnippy  tvalfc  ... tfcaldt  tnotice iymcn  \
# 0  2023-11-16   1.0      0.0     0.0     0.0  ...    None      0.0  None
# 1  2024-05-16   0.0      0.0     0.0     0.0  ...    None      0.0  None
#
#    itype iuniq  itax  iflwr  tbankdt  tstripelig tfrgntgt
# 0    4.0   0.0   1.0    1.0     None        None     None
# 1    4.0   0.0   1.0    1.0     None        None     None
#
# [2 rows x 22 columns]

# %% [markdown]
# # Get Timeseries for TIPS issues

# %%
KEYNO_tips = (207431,206999,207009)

SQL_QUERY = f'select * from crsp_m_treasuries.tfz_dly where kytreasno in {KEYNO_tips}'

ts_issue_tips = db.raw_sql(SQL_QUERY)
ts_issue_tips
# Out:
#       kytreasno         kycrspid       caldt       tdbid       tdask  \
# 0      207431.0  20241015.C00120  2019-10-21  100.171875  100.242188
# 1      206999.0  20260715.C00120  2016-07-14  101.171875  101.203125
# 2      206999.0  20260715.C00120  2016-07-15  100.890625  100.921875
# 3      206999.0  20260715.C00120  2016-07-18  101.253906  101.285156
# 4      206999.0  20260715.C00120  2016-07-19  101.421875  101.453125
# ...         ...              ...         ...         ...         ...
# 4711   207009.0  20260815.201500  2019-10-15   98.812500   98.875000
# 4712   207009.0  20260815.201500  2019-10-16   99.062500   99.125000
# 4713   207431.0  20241015.C00120  2019-10-24  100.332031  100.402344
# 4714   207431.0  20241015.C00120  2019-10-25  100.257812  100.332031
# 4715   207431.0  20241015.C00120  2019-10-29   99.820312   99.890625
#
#         tdnomprc tdnomprc_flg tdsourcr  tdaccint  tdretnua     tdyld  \
# 0     100.207031            M        I  0.000000       NaN       NaN
# 1     101.187500            M        I  0.000000       NaN       NaN
# 2     100.906250            M        I  0.000000       NaN       NaN
# 3     101.269531            M        I  0.000000       NaN       NaN
# 4     101.437500            M        I  0.000000       NaN       NaN
# ...          ...          ...      ...       ...       ...       ...
# 4711   98.843750            M        I  0.248641 -0.002667  0.000046
# 4712   99.093750            M        I  0.252717  0.002564  0.000045
# 4713  100.367188            M        I  0.000000       NaN       NaN
# 4714  100.294922            M        I  0.000000       NaN       NaN
# 4715   99.855469            M        I  0.000000       NaN       NaN
#
#          tdduratn  tdpubout  tdtotout  tdpdint  tdidxratio tdidxratio_flg
# 0             NaN       NaN       NaN      0.0     0.99999              C
# 1             NaN       NaN       NaN      0.0     0.99987              C
# 2             NaN       NaN       NaN      0.0     1.00000              C
# 3             NaN       NaN       NaN      0.0     1.00039              C
# 4             NaN       NaN       NaN      0.0     1.00052              C
# ...           ...       ...       ...      ...         ...            ...
# 4711  2375.080233   63023.0   65349.0      0.0         NaN           None
# 4712  2374.276965   63023.0   65349.0      0.0         NaN           None
# 4713          NaN       NaN       NaN      0.0     0.99999              C
# 4714          NaN       NaN       NaN      0.0     0.99998              C
# 4715          NaN       NaN       NaN      0.0     0.99998              C
#
# [4716 rows x 17 columns]

# %%
SQL_QUERY = f'select * from crsp_m_treasuries.tfz_iss where kytreasno in {KEYNO_tips}'
temp = db.raw_sql(SQL_QUERY)
#temp = temp[temp['itype'].isin([11,12]) == DOTIPS]
temp
# Out:
#    kytreasno         kycrspid           crspid    tcusip      tdatdt  \
# 0   206999.0  20260715.C00120  20260715.C00120  912828S5  2016-07-15
# 1   207009.0  20260815.201500  20260815.201500  9128282A  2016-08-15
# 2   207431.0  20241015.C00120  20241015.C00120  912828YL  2019-10-15
#
#        tmatdt  iwhy  tcouprt  tnippy  tvalfc  ... tfcaldt  tnotice iymcn  \
# 0  2026-07-15   0.0    0.125     2.0  0.0625  ...    None      0.0  None
# 1  2026-08-15   0.0    1.500     2.0  0.7500  ...    None      0.0  None
# 2  2024-10-15   0.0    0.125     2.0  0.0625  ...    None      0.0  None
#
#    itype iuniq  itax  iflwr  tbankdt  tstripelig tfrgntgt
# 0   12.0   0.0   1.0    1.0     None        None     None
# 1    2.0   0.0   1.0    1.0     None        None     None
# 2   12.0   0.0   1.0    1.0     None        None     None
#
# [3 rows x 22 columns]

# %% [markdown]
# # Get Timeseries for Duration Analysis

# %% [markdown]
# Update the KEYNOs.
# * These three are issued in Aug 2019.
# * Idea is 5, 10, 30 maturities.
# * 5-year matures in Aug 2024. So will need updated.
#
# Used in HW 2, problem 3.
# * Only make use of the 30yr and 10yr there.

# %%
KEYNO_ts_duration = (207392, 207391, 207404)
SQL_QUERY = f'select * from crsp_m_treasuries.tfz_dly where kytreasno in {KEYNO_ts_duration}'
ts_issue_duration = db.raw_sql(SQL_QUERY)
ts_issue_duration

infoflds = ['tdatdt','tmatdt','tcouprt','itype']
labels = ['issue date','maturity date','coupon rate','security type']
rename_dict = {infoflds[i]:labels[i] for i in range(len(infoflds))}
info_ts_duration = data_iss.set_index('kytreasno').loc[list(KEYNO_ts_duration),infoflds].rename(columns=rename_dict)

# %% [markdown]
# # Fama Bliss

# %%
db.describe_table(library='crsp_m_treasuries', table='tfz_mth_fb')

SQL_QUERY = f'select * from crsp_m_treasuries.tfz_mth_fb'
fb_raw = db.raw_sql(SQL_QUERY)
fb = fb_raw.rename(columns={'mcaldt':'date','tmnomprc':'price','tmytm':'yld'})
fb = fb.pivot_table(values='price',index='date',columns='kytreasnox')
fb.rename(columns={2000047:1, 2000048:2, 2000049:3, 2000050:4, 2000051:5},inplace=True)
fb.columns.name = 'maturity'
fb
# Out:
# Approximately 4295 rows in crsp_m_treasuries.tfz_mth_fb.
# maturity            1          2          3          4          5
# date
# 1952-06-30  98.177763  96.253133  94.246713  92.634134  90.418295
# 1952-07-31  98.094756  96.031453  93.931226  92.308865  89.851576
# 1952-08-29  98.057808  95.974988  93.781939  92.145776  89.571687
# 1952-09-30  98.031188  95.909789  93.755108  92.096104  89.167641
# 1952-10-31  98.110769  95.974490  93.758273  91.929019  89.724841
# ...               ...        ...        ...        ...        ...
# 2023-08-31  94.816353  90.853466  87.433461  84.104382  81.043140
# 2023-09-29  94.730925  90.527697  86.825311  83.080264  79.615657
# 2023-10-31  94.771792  90.435524  86.473944  82.436256  78.612617
# 2023-11-30  95.107986  91.195087  87.695668  84.219066  80.937758
# 2023-12-29  95.378749  91.964449  88.852295  85.667229  82.673963
#
# [859 rows x 5 columns]

# %% [markdown]
# # Save to Excel

# %%
outfile = f'../data/treasury_quotes_{DATE}.xlsx'
with pd.ExcelWriter(outfile) as writer:  
    data.to_excel(writer, sheet_name= 'quotes', index=False)

# %%
outfile = f'../data/treasury_ts_{MATDT}.xlsx'
with pd.ExcelWriter(outfile) as writer:  
    ts.to_excel(writer, sheet_name= 'ts', index=False)

# %%
outfile = f'../data/treasury_ts_issue_{KEYNO_ts}.xlsx'
with pd.ExcelWriter(outfile) as writer:  
    ts_issue.to_excel(writer, sheet_name= 'ts', index=False)

# %%
outfile = f'../data/treasury_ts_issue_TIPS_{KEYNO_tips}.xlsx'
with pd.ExcelWriter(outfile) as writer:  
    ts_issue_tips.to_excel(writer, sheet_name= 'ts', index=False)

# %%
outfile = f'../data/yields.xlsx'
with pd.ExcelWriter(outfile) as writer:
    data_ft.to_excel(writer, sheet_name= 'yields', index=True)

# %%
outfile = f'../data/treasury_ts_issue_duration_{KEYNO_ts_duration}.xlsx'
with pd.ExcelWriter(outfile) as writer:  
    info_ts_duration.to_excel(writer, sheet_name= 'info', index=True)
    ts_issue_duration.to_excel(writer, sheet_name= 'ts', index=False)

# %%
outfile = f'../data/famabliss_strips_{DATE}.xlsx'
with pd.ExcelWriter(outfile) as writer:
    fb.to_excel(writer, sheet_name= 'prices', index=True)

# %%
outfile = f'../data/select_maturities_{DATE}.xlsx'
with pd.ExcelWriter(outfile) as writer:
    selected.to_excel(writer, sheet_name= 'selected treasuries', index=True)
